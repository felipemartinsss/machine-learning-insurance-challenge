# %% [markdown]
# # Desafio 2 - Regressão: Treinamento de Modelo

# %% [markdown]
# ## Carregamento de features em diferentes formatos e target

# %%
import pickle
file_path = '/content/drive/MyDrive/curso_machine-learning-python/datasets/proccessed_insurance_data.pkl'
processed_insurance_data = open(file_path, 'rb')
target = pickle.load(processed_insurance_data)
all_features = pickle.load(processed_insurance_data)
scaled_all_features = pickle.load(processed_insurance_data)
high_corr_features = pickle.load(processed_insurance_data)
scaled_high_corr_features = pickle.load(processed_insurance_data)
processed_insurance_data.close()

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Verificação de dois dos conjuntos carregados

# %%
target_df = pd.DataFrame(target)
target_df.shape
# Out:
# (1338, 1)

# %%
all_features_df = pd.DataFrame(all_features)
all_features_df.shape
# Out:
# (1338, 11)

# %% [markdown]
# ## Separação de dados em treino e teste

# %%
def divide_dataset_treino_teste(source_features, source_target):
  from sklearn.model_selection import train_test_split
  features_treino, features_teste, target_treino, target_teste = train_test_split(
    source_features, source_target, test_size = 0.3, random_state = 0
  )
  return features_treino, features_teste, target_treino, target_teste

# %%
features_treino, features_teste, target_treino, target_teste = divide_dataset_treino_teste(all_features, target)

# %% [markdown]
# ## Treinamento de modelos

# %% [markdown]
# ### Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg_model = LinearRegression()

# %%
lin_reg_model.fit(features_treino, target_treino)
# Out:
# LinearRegression()

# %%
score_treino = lin_reg_model.score(features_treino, target_treino)
score_treino
# Out:
# 0.7309569871174701

# %%
score_teste = lin_reg_model.score(features_teste, target_teste)
score_teste
# Out:
# 0.7909160991789905

# %% [markdown]
# #### Resultados

# %% [markdown]
# **Modelo:** Regressão Linear Múltipla
#
# ---
#
# **Conjunto de features:** all_features
#
# **score em treino:** 0.73
#
# **score em teste:** 0.79
#
# ---
#
# **Conjunto de features:** scaled_all_features
#
# **score em treino:** 0.73
#
# **score em teste:** 0.79
#
# ---
#
#
# **Conjunto de features:** high_corr_features
#
# **score em treino:** 0.70
#
# **score em teste:** 0.76
#
# ---
#
#
# **Conjunto de features:** scaled_high_corr_features
#
# **score em treino:** 0.70
#
# **score em teste:** 0.76

# %% [markdown]
# As features possuem muitas dimensões, não vai ser possível fazer um gráfico com a reta de regressão.

# %% [markdown]
# #### Métricas de Desempenho

# %%
from sklearn.metrics import root_mean_squared_error

# %%
predicted_target = lin_reg_model.predict(features_teste)
rmse = root_mean_squared_error(target_teste, predicted_target)
print(f"Erro médio usando all_features: {rmse}")
# Out:
# Erro médio usando all_features: 5774.2963057808665

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
k_fold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
modelo = LinearRegression()

# %%
resultado = cross_val_score(modelo, all_features, target, cv = k_fold)

# %%
print(f"Coeficiente R² médio: {resultado.mean()}")
print(f"Coeficiente R² inferior: {resultado.mean() - resultado.std()}")
print(f"Coeficiente R² superior: {resultado.mean() + resultado.std()}")
# Out:
# Coeficiente R² médio: 0.7356373982088413
# Coeficiente R² inferior: 0.680117796174853
# Coeficiente R² superior: 0.7911570002428296

# %% [markdown]
# #### Conclusão
#
# Modelo baseado em Regressão Linear Múltipla conseguiu se ajustar em 79% à target. É um dos modelos mais simples, então parece um bom resultado. Vamos testar outros modelos em seguida.

# %%
resultados_finais_df = pd.DataFrame()
linear_regression_performance = pd.DataFrame({
  'model': ['multiple_linear_regression'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [resultado.mean()],
  'R^2_std_dev': [resultado.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, linear_regression_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
#
#    R^2_std_dev
# 0      0.05552

# %% [markdown]
# ### Support Vector Regressor

# %%
from sklearn.svm import SVR

# %%
# default kernel is rbf
sup_vec_regressor = SVR(kernel = 'rbf')

# %%
sup_vec_regressor.fit(features_treino, target_treino)
# Out:
# SVR()

# %%
sup_vec_regressor.score(features_treino, target_treino)
# Out:
# -0.09426391963281566

# %%
sup_vec_regressor.score(features_teste, target_teste)
# Out:
# -0.08859789219262182

# %% [markdown]
# Do que o Support Vector Regressor precisa mesmo? Padronizar escalas de variáveis, tanto dependentes quando independentes.

# %%
from sklearn.preprocessing import StandardScaler
feature_scaler = StandardScaler()
scaled_features_treino = feature_scaler.fit_transform(features_treino)

# %%
target_scaler = StandardScaler()
scaled_target_treino = target_scaler.fit_transform(target_treino.reshape(-1, 1))

# %%
SVR_wscaled = SVR(kernel = 'rbf')
SVR_wscaled.fit(scaled_features_treino, scaled_target_treino)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
score_treino = SVR_wscaled.score(scaled_features_treino, scaled_target_treino)
score_treino
# Out:
# 0.8374931487203512

# %%
scaled_features_teste = feature_scaler.fit_transform(features_teste)

# %%
scaled_target_teste = target_scaler.fit_transform(target_teste.reshape(-1,1))

# %%
score_teste = SVR_wscaled.score(scaled_features_teste, scaled_target_teste)
score_teste
# Out:
# 0.8752604597810801

# %% [markdown]
# O coeficiente de determinação $R^2$ ficou melhor no SVR.

# %% [markdown]
# #### Resultados

# %% [markdown]
# **Modelo:** Support Vector Regressor
#
# ---
#
# **Conjunto de features:** scaled_all_features and scaled_target
#
# **score em treino:** 0.84
#
# **score em teste:** 0.88

# %% [markdown]
# #### Métricas de Desempenho

# %%
from sklearn.metrics import root_mean_squared_error

# %%
predicted_target = SVR_wscaled.predict(scaled_features_teste)

# %%
target_teste_inversed = target_scaler.inverse_transform(scaled_target_teste)

# %%
predicted_target_inversed = target_scaler.inverse_transform(predicted_target.reshape(-1, 1))

# %%
rmse = root_mean_squared_error(target_teste_inversed, predicted_target_inversed)
rmse
# Out:
# 4460.061407282226

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
X_scaler = StandardScaler()

# %%
y_scaler = StandardScaler()

# %%
X_scaled = X_scaler.fit_transform(all_features)

# %%
y_scaled = y_scaler.fit_transform(target.reshape(-1, 1))

# %%
modelo = SVR(kernel = 'rbf')

# %%
k_fold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
resultado = cross_val_score(modelo, X_scaled, y_scaled.ravel(), cv = k_fold)

# %%
print(f"Coeficiente R² médio: {resultado.mean()}")
print(f"Coeficiente R² inferior: {resultado.mean() - resultado.std()}")
print(f"Coeficiente R² superior: {resultado.mean() + resultado.std()}")
# Out:
# Coeficiente R² médio: 0.8356454051983156
# Coeficiente R² inferior: 0.7880730379941618
# Coeficiente R² superior: 0.8832177724024695

# %% [markdown]
# #### Conclusão
#
# O regressor baseado em support vector machines se saiu melhor do que a regressão linear, tanto no coeficiente R² quanto na métrica de erro RMSE.
# Entre os 2, deve ser escolhido SVR. Apesar disso, o contra do SVR é que exige várias transformações de escala para poder ser utilizado. Talvez por isso, muitas vezes as pessoas escolhem outros modelos.

# %%
linear_regression_performance = pd.DataFrame({
  'model': ['support_vector_regressor'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [resultado.mean()],
  'R^2_std_dev': [resultado.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, linear_regression_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
# 0    support_vector_regressor     0.837493    0.875260  4460.061407  0.835645
#
#    R^2_std_dev
# 0     0.055520
# 0     0.047572

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor(max_depth = 4, criterion='poisson', random_state = 0)

# %%
tree.fit(features_treino, target_treino)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=4, random_state=0)

# %%
score_treino = tree.score(features_treino, target_treino)
score_treino
# Out:
# 0.8531650151210386

# %%
score_teste = tree.score(features_teste, target_teste)
score_teste
# Out:
# 0.8854782318253775

# %% [markdown]
# squared_error:
# - treino: 0.852 ~ 0.85
# - teste: 0.884 ~ 0.88
#
# poisson:
# - treino: 0.853 ~ 0.85
# - teste: 0.885 ~ 0.89

# %% [markdown]
# #### Resultados
#
# all_features == scaled_all_features
#
# R² em treino: 0.85
#
# R² em teste: 0.89

# %% [markdown]
# #### Métricas de Desempenho

# %%
from sklearn.metrics import root_mean_squared_error

# %%
predicted_target_teste = tree.predict(features_teste)
rmse = root_mean_squared_error(target_teste, predicted_target_teste)
rmse
# Out:
# 4273.490975094296

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
k_fold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
modelo = DecisionTreeRegressor(max_depth = 4, criterion='poisson', random_state = 0)

# %%
resultado = cross_val_score(modelo, all_features, target)

# %%
print(f"Coeficiente R² médio: {resultado.mean()}")
print(f"Coeficiente R² inferior: {resultado.mean() - resultado.std()}")
print(f"Coeficiente R² superior: {resultado.mean() + resultado.std()}")
# Out:
# Coeficiente R² médio: 0.8510140323464425
# Coeficiente R² inferior: 0.8141620277296231
# Coeficiente R² superior: 0.8878660369632618

# %% [markdown]
# #### Conclusão

# %% [markdown]
# O Regressor baseado em árvore de decisão superou o Suppor Vector Regressor. A diferença foi pequena, mas ele obteve melhores coeficiente R² além de menor erro com RSME. Além disso, ainda tem a vantagem de exigir menos pré/pós-processamento.

# %%
model_performance = pd.DataFrame({
  'model': ['decision_tree_regressor'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [resultado.mean()],
  'R^2_std_dev': [resultado.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, model_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
# 0    support_vector_regressor     0.837493    0.875260  4460.061407  0.835645
# 0     decision_tree_regressor     0.853165    0.885478  4273.490975  0.851014
#
#    R^2_std_dev
# 0     0.055520
# 0     0.047572
# 0     0.036852

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
random_forest = RandomForestRegressor(n_estimators = 100, criterion = 'friedman_mse', max_depth = 6, random_state = 0)

# %%
random_forest.fit(features_treino, target_treino)
# Out:
# RandomForestRegressor(criterion='friedman_mse', max_depth=6, random_state=0)

# %%
score_treino = random_forest.score(features_treino, target_treino)
score_treino
# Out:
# 0.9047018875232218

# %%
score_teste = random_forest.score(features_teste, target_teste)
score_teste
# Out:
# 0.8798194991833832

# %% [markdown]
# #### Resultados

# %% [markdown]
# all_features == scaled_all_features
#
# Random Forest
#
# - score em treino: 0.90
#
# - score em teste: 0.88

# %% [markdown]
# #### Métricas de Desempenho

# %%
from sklearn.metrics import root_mean_squared_error

# %%
predicted_target_teste = random_forest.predict(features_teste)
rmse = root_mean_squared_error(target_teste, predicted_target_teste)
rmse
# Out:
# 4377.798554276961

# %%
# Observação: às vezes o algoritmo pode ter um bom score e ter um RMSE ruim. Mudei
# o n_estimators de 250 para 100 para diminuir esse erro. Me parece que estava tendendo ao
# overfitting.

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
k_fold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
modelo = RandomForestRegressor(n_estimators = 100, criterion = 'friedman_mse', max_depth = 6, random_state = 0)

# %%
resultado = cross_val_score(modelo, all_features, target, cv = k_fold)

# %%
print(f"Coeficiente R² médio: {resultado.mean()}")
print(f"Coeficiente R² inferior: {resultado.mean() - resultado.std()}")
print(f"Coeficiente R² superior: {resultado.mean() + resultado.std()}")
# Out:
# Coeficiente R² médio: 0.8502056088233102
# Coeficiente R² inferior: 0.807442464238317
# Coeficiente R² superior: 0.8929687534083034

# %% [markdown]
# #### Conclusão

# %% [markdown]
# Random Forest ficou muito parecido com o Decision Tree e ambos foram melhores que o SVR.
# Devido à simplicidade, acredito que escolheria o Decision Tree até o momento.
# Nas próximas seções, vamos ver 3 dos algoritmos mais poderosos, XGBoost, LightGBM e CatBoost.

# %%
model_performance = pd.DataFrame({
  'model': ['random_forest'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [resultado.mean()],
  'R^2_std_dev': [resultado.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, model_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
# 0    support_vector_regressor     0.837493    0.875260  4460.061407  0.835645
# 0     decision_tree_regressor     0.853165    0.885478  4273.490975  0.851014
# 0               random_forest     0.904702    0.879819  4377.798554  0.850206
#
#    R^2_std_dev
# 0     0.055520
# 0     0.047572
# 0     0.036852
# 0     0.042763

# %% [markdown]
# ### XGBoost

# %%
from xgboost import XGBRegressor

# %%
xgboost = XGBRegressor(n_estimators = 75, max_depth = 4, learning_rate = 0.05, objective='reg:squarederror')

# %%
xgboost.fit(features_treino, target_treino)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.05, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=75, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
score_treino = xgboost.score(features_treino, target_treino)
score_treino
# Out:
# 0.8813457947769354

# %%
score_teste = xgboost.score(features_teste, target_teste)
score_teste
# Out:
# 0.8901612137439361

# %% [markdown]
# #### Resultados

# %% [markdown]
# all_features == scaled_all_features
#
# Score do XGBoost:
#
# - treino: 0.88
#
# - teste: 0.89

# %% [markdown]
# #### Métricas de Desempenho

# %%
from sklearn.metrics import root_mean_squared_error

# %%
predicted_target_testes = xgboost.predict(features_teste)

# %%
rmse = root_mean_squared_error(target_teste, predicted_target_testes)
rmse
# Out:
# 4185.203996526568

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
k_fold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
modelo = XGBRegressor(n_estimators = 75, max_depth = 4, learning_rate = 0.05, objective='reg:squarederror')

# %%
cv_score = cross_val_score(modelo, all_features, target, cv = k_fold)

# %%
print(f"Coeficiente R² médio: {cv_score.mean()}")
print(f"Coeficiente R² inferior: {cv_score.mean() - cv_score.std()}")
print(f"Coeficiente R² superior: {cv_score.mean() + cv_score.std()}")
# Out:
# Coeficiente R² médio: 0.8577180490554157
# Coeficiente R² inferior: 0.8180795485226553
# Coeficiente R² superior: 0.8973565495881761

# %% [markdown]
# #### Conclusão

# %% [markdown]
# O XGBoost apresentou resultados levemente superiores ao outros que estavam melhor no coeficiente de determinação R².
# Com relação aos erros, também. O XGBoost apresenta até agora o menor erro, 4185.20.

# %%
model_performance = pd.DataFrame({
  'model': ['xgboost'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [cv_score.mean()],
  'R^2_std_dev': [cv_score.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, model_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
# 0    support_vector_regressor     0.837493    0.875260  4460.061407  0.835645
# 0     decision_tree_regressor     0.853165    0.885478  4273.490975  0.851014
# 0               random_forest     0.904702    0.879819  4377.798554  0.850206
# 0                     xgboost     0.881346    0.890161  4185.203997  0.857718
#
#    R^2_std_dev
# 0     0.055520
# 0     0.047572
# 0     0.036852
# 0     0.042763
# 0     0.039639

# %% [markdown]
# ### LightGBM

# %%
import lightgbm as lgb

# %%
lgbm = lgb.LGBMRegressor(num_leaves = 15, max_depth = 3, learning_rate = 0.1, n_estimators = 60)

# %%
lgbm.fit(features_treino, target_treino)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000161 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 325
# [LightGBM] [Info] Number of data points in the train set: 936, number of used features: 11
# [LightGBM] [Info] Start training from score 13232.916456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# LGBMRegressor(max_depth=3, n_estimators=60, num_leaves=15)

# %%
score_treino = lgbm.score(features_treino, target_treino)
score_treino
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 0.8736670088324157

# %%
score_teste = lgbm.score(features_teste, target_teste)
score_teste
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 0.8937278307747821

# %% [markdown]
# #### Resultados

# %% [markdown]
# O LightGBM ficou melhor usando scaled_all_features em vez de all_features.
# O resultado foi:
#
# - score treino: 0.873 ~ 0.87
#
# - score teste: 0.897 ~ 0.90

# %% [markdown]
# #### Métricas de Desempenho

# %%
from sklearn.metrics import root_mean_squared_error

# %%
predicted_target_teste = lgbm.predict(features_teste)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
rmse = root_mean_squared_error(predicted_target_teste, target_teste)
rmse
# Out:
# 4116.693574020556

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kfold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
model = lgb.LGBMRegressor(num_leaves = 15, max_depth = 3, learning_rate = 0.1, n_estimators = 60)

# %%
cross_val_result = cross_val_score(model, scaled_all_features, target, cv = kfold);
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000225 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13010.342228
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000180 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13468.968214
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000209 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13302.799000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13305.774773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13379.246585
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000182 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13494.763434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000172 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13212.707395
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000183 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1204, number of used features: 11
# [LightGBM] [Info] Start training from score 13195.137987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000173 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1205, number of used features: 11
# [LightGBM] [Info] Start training from score 13209.423779
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000184 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 334
# [LightGBM] [Info] Number of data points in the train set: 1205, number of used features: 11
# [LightGBM] [Info] Start training from score 13125.230456
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
print(f"Coeficiente R² médio: {cross_val_result.mean()}")
print(f"Coeficiente R² inferior: {cross_val_result.mean() - cross_val_result.std()}")
print(f"Coeficiente R² superior: {cross_val_result.mean() + cross_val_result.std()}")
# Out:
# Coeficiente R² médio: 0.8574484096097168
# Coeficiente R² inferior: 0.8180650507145069
# Coeficiente R² superior: 0.8968317685049267

# %% [markdown]
# #### Conclusão

# %% [markdown]
# Ocorreu praticamente um empate técnico entre o LightGBM e o XGBoost.
# Apesar disso, na métrica de desempenho, o LightGBM foi ligeiramente melhor usando scaled_all_features.

# %%
model_performance = pd.DataFrame({
  'model': ['lightgbm'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [cross_val_result.mean()],
  'R^2_std_dev': [cross_val_result.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, model_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
# 0    support_vector_regressor     0.837493    0.875260  4460.061407  0.835645
# 0     decision_tree_regressor     0.853165    0.885478  4273.490975  0.851014
# 0               random_forest     0.904702    0.879819  4377.798554  0.850206
# 0                     xgboost     0.881346    0.890161  4185.203997  0.857718
# 0                    lightgbm     0.873667    0.893728  4116.693574  0.857448
#
#    R^2_std_dev
# 0     0.055520
# 0     0.047572
# 0     0.036852
# 0     0.042763
# 0     0.039639
# 0     0.039383

# %% [markdown]
# ### CatBoost

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.11/dist-packages (1.2.8)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)

# %%
from catboost.core import CatBoostRegressor

# %%
catboost = CatBoostRegressor(iterations = 75, learning_rate = 0.10, depth = 7, random_state = 0)

# %%
catboost.fit(features_treino, target_treino);
# Out:
# 0:	learn: 11096.7213541	total: 1.61ms	remaining: 119ms
# 1:	learn: 10370.8239612	total: 2.32ms	remaining: 84.7ms
# 2:	learn: 9755.7383836	total: 3.47ms	remaining: 83.2ms
# 3:	learn: 9187.2664872	total: 4.73ms	remaining: 84ms
# 4:	learn: 8656.3861320	total: 5.8ms	remaining: 81.1ms
# 5:	learn: 8171.8658700	total: 6.13ms	remaining: 70.5ms
# 6:	learn: 7735.7643300	total: 7.21ms	remaining: 70ms
# 7:	learn: 7327.5305135	total: 8.41ms	remaining: 70.4ms
# 8:	learn: 6971.1983763	total: 9.89ms	remaining: 72.5ms
# 9:	learn: 6669.5714673	total: 10.2ms	remaining: 66.2ms
# 10:	learn: 6413.4874399	total: 10.4ms	remaining: 60.8ms
# 11:	learn: 6158.3320446	total: 11.2ms	remaining: 58.6ms
# 12:	learn: 5952.3027175	total: 12.5ms	remaining: 59.6ms
# 13:	learn: 5783.4733560	total: 13.8ms	remaining: 60ms
# 14:	learn: 5637.5084818	total: 14.2ms	remaining: 56.7ms
# 15:	learn: 5477.2082258	total: 15.4ms	remaining: 56.7ms
# 16:	learn: 5360.5466676	total: 16.6ms	remaining: 56.8ms
# 17:	learn: 5235.5888753	total: 17.8ms	remaining: 56.5ms
# 18:	learn: 5133.7165491	total: 18.9ms	remaining: 55.8ms
# 19:	learn: 5044.1185781	total: 19.4ms	remaining: 53.5ms
# 20:	learn: 4974.2372442	total: 19.8ms	remaining: 50.9ms
# 21:	learn: 4892.3625895	total: 21ms	remaining: 50.6ms
# 22:	learn: 4830.3064929	total: 22.1ms	remaining: 50.1ms
# 23:	learn: 4762.0795744	total: 23.2ms	remaining: 49.4ms
# 24:	learn: 4705.2667953	total: 24.3ms	remaining: 48.7ms
# 25:	learn: 4654.5877175	total: 25.5ms	remaining: 48.1ms
# 26:	learn: 4609.3419523	total: 26.5ms	remaining: 47.2ms
# 27:	learn: 4559.5648839	total: 27.3ms	remaining: 45.8ms
# 28:	learn: 4516.1416795	total: 28.3ms	remaining: 44.9ms
# 29:	learn: 4480.7853096	total: 29.4ms	remaining: 44.1ms
# 30:	learn: 4448.6419273	total: 30.5ms	remaining: 43.3ms
# 31:	learn: 4423.4479412	total: 31.6ms	remaining: 42.4ms
# 32:	learn: 4407.6223450	total: 32ms	remaining: 40.7ms
# 33:	learn: 4376.2330233	total: 33.1ms	remaining: 39.9ms
# 34:	learn: 4362.5313630	total: 34.3ms	remaining: 39.2ms
# 35:	learn: 4337.5344107	total: 35.5ms	remaining: 38.4ms
# 36:	learn: 4315.9040577	total: 36.5ms	remaining: 37.5ms
# 37:	learn: 4307.1151018	total: 36.9ms	remaining: 35.9ms
# 38:	learn: 4287.5945920	total: 37.9ms	remaining: 35ms
# 39:	learn: 4268.7850143	total: 39ms	remaining: 34.1ms
# 40:	learn: 4246.4510923	total: 40ms	remaining: 33.2ms
# 41:	learn: 4226.0442850	total: 41.1ms	remaining: 32.3ms
# 42:	learn: 4205.3126123	total: 42.1ms	remaining: 31.4ms
# 43:	learn: 4199.1399186	total: 42.8ms	remaining: 30.2ms
# 44:	learn: 4177.9363192	total: 44.1ms	remaining: 29.4ms
# 45:	learn: 4158.0585978	total: 45.2ms	remaining: 28.5ms
# 46:	learn: 4148.6499102	total: 46.2ms	remaining: 27.5ms
# 47:	learn: 4135.2983256	total: 47.3ms	remaining: 26.6ms
# 48:	learn: 4112.8383804	total: 48.4ms	remaining: 25.7ms
# 49:	learn: 4102.6036454	total: 49.1ms	remaining: 24.5ms
# 50:	learn: 4093.7194972	total: 50.1ms	remaining: 23.6ms
# 51:	learn: 4076.5801870	total: 51.2ms	remaining: 22.6ms
# 52:	learn: 4065.7392072	total: 52.2ms	remaining: 21.7ms
# 53:	learn: 4055.0390700	total: 53.3ms	remaining: 20.7ms
# 54:	learn: 4039.6526362	total: 54.3ms	remaining: 19.8ms
# 55:	learn: 4028.9643961	total: 55.4ms	remaining: 18.8ms
# 56:	learn: 4018.7006375	total: 56.4ms	remaining: 17.8ms
# 57:	learn: 4005.6513685	total: 57.5ms	remaining: 16.9ms
# 58:	learn: 3994.3620317	total: 58.7ms	remaining: 15.9ms
# 59:	learn: 3980.4677555	total: 59.8ms	remaining: 14.9ms
# 60:	learn: 3960.5390974	total: 60.9ms	remaining: 14ms
# 61:	learn: 3952.9517114	total: 62ms	remaining: 13ms
# 62:	learn: 3939.2884430	total: 63.1ms	remaining: 12ms
# 63:	learn: 3931.9121560	total: 64.1ms	remaining: 11ms
# 64:	learn: 3924.7331652	total: 65.2ms	remaining: 10ms
# 65:	learn: 3911.7590666	total: 66.4ms	remaining: 9.05ms
# 66:	learn: 3902.4573734	total: 67.4ms	remaining: 8.05ms
# 67:	learn: 3895.5417872	total: 68.5ms	remaining: 7.05ms
# 68:	learn: 3878.4365354	total: 69.5ms	remaining: 6.05ms
# 69:	learn: 3868.1674961	total: 70.8ms	remaining: 5.05ms
# 70:	learn: 3865.5712078	total: 71.3ms	remaining: 4.01ms
# 71:	learn: 3858.2121466	total: 72.4ms	remaining: 3.02ms
# 72:	learn: 3852.7185145	total: 73.5ms	remaining: 2.01ms
# 73:	learn: 3845.7575570	total: 74.6ms	remaining: 1.01ms
# 74:	learn: 3829.6480469	total: 75.6ms	remaining: 0us

# %%
score_treino = catboost.score(features_treino, target_treino)
score_treino
# Out:
# np.float64(0.8959742114451366)

# %%
score_teste = catboost.score(features_teste, target_teste)
score_teste
# Out:
# np.float64(0.8871886423839948)

# %% [markdown]
# #### Resultados

# %% [markdown]
# all_features = scaled_all_features
#
# CatBoost:
#
# - Score em Treino: 0.895 ~ 0.90
#
# - Score em Teste: 0.887 ~ 0.89

# %% [markdown]
# #### Métricas de Desempenho

# %%
predicted_target_teste = catboost.predict(features_teste)

# %%
from sklearn.metrics import root_mean_squared_error

# %%
rmse = root_mean_squared_error(target_teste, predicted_target_teste)
rmse
# Out:
# 4241.458105099225

# %% [markdown]
# #### Validação Cruzada

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
kfold = KFold(n_splits = 10, shuffle = True, random_state = 0)

# %%
modelo = CatBoostRegressor(iterations = 75, learning_rate = 0.10, depth = 7, random_state = 0)

# %%
resultado = cross_val_score(modelo, all_features, target, cv = kfold)
# Out:
# 0:	learn: 11054.0644801	total: 2.47ms	remaining: 183ms
# 1:	learn: 10318.3546299	total: 3.33ms	remaining: 121ms
# 2:	learn: 9675.8384761	total: 4.53ms	remaining: 109ms
# 3:	learn: 9073.3132547	total: 5.82ms	remaining: 103ms
# 4:	learn: 8488.3645577	total: 7.19ms	remaining: 101ms
# 5:	learn: 8006.9822973	total: 7.57ms	remaining: 87.1ms
# 6:	learn: 7550.5914270	total: 8.98ms	remaining: 87.3ms
# 7:	learn: 7145.9845984	total: 10.2ms	remaining: 85.6ms
# 8:	learn: 6785.2262303	total: 11.4ms	remaining: 83.4ms
# 9:	learn: 6505.4242602	total: 12.7ms	remaining: 82.8ms
# 10:	learn: 6219.9556953	total: 14ms	remaining: 81.4ms
# 11:	learn: 5970.7969237	total: 14.9ms	remaining: 78.3ms
# 12:	learn: 5785.6949346	total: 16.2ms	remaining: 77.3ms
# 13:	learn: 5616.8586596	total: 16.6ms	remaining: 72.2ms
# 14:	learn: 5464.2324896	total: 17.8ms	remaining: 71.1ms
# 15:	learn: 5315.9453845	total: 18.9ms	remaining: 69.7ms
# 16:	learn: 5183.9543530	total: 19.7ms	remaining: 67.1ms
# 17:	learn: 5069.5659354	total: 20.4ms	remaining: 64.6ms
# 18:	learn: 4980.7712846	total: 20.9ms	remaining: 61.7ms
# 19:	learn: 4907.2735711	total: 22ms	remaining: 60.5ms
# 20:	learn: 4830.2977917	total: 23.2ms	remaining: 59.7ms
# 21:	learn: 4784.4370335	total: 23.6ms	remaining: 56.8ms
# 22:	learn: 4715.7872373	total: 24.7ms	remaining: 55.8ms
# 23:	learn: 4663.4831232	total: 25.3ms	remaining: 53.8ms
# 24:	learn: 4620.7407219	total: 26.4ms	remaining: 52.9ms
# 25:	learn: 4572.7016005	total: 27.6ms	remaining: 52.1ms
# 26:	learn: 4532.3901177	total: 28.8ms	remaining: 51.1ms
# 27:	learn: 4500.4857134	total: 29.3ms	remaining: 49.2ms
# 28:	learn: 4463.7379585	total: 30.4ms	remaining: 48.2ms
# 29:	learn: 4435.2998216	total: 31.4ms	remaining: 47.2ms
# 30:	learn: 4411.8231648	total: 32.5ms	remaining: 46.2ms
# 31:	learn: 4384.5017894	total: 33.6ms	remaining: 45.2ms
# 32:	learn: 4367.3976990	total: 34.7ms	remaining: 44.2ms
# 33:	learn: 4348.4294232	total: 35.9ms	remaining: 43.3ms
# 34:	learn: 4328.9697341	total: 37.1ms	remaining: 42.4ms
# 35:	learn: 4316.7447029	total: 38.2ms	remaining: 41.4ms
# 36:	learn: 4299.3455037	total: 39.4ms	remaining: 40.5ms
# 37:	learn: 4277.6743545	total: 40.6ms	remaining: 39.5ms
# 38:	learn: 4263.3313605	total: 41.8ms	remaining: 38.6ms
# 39:	learn: 4252.4941606	total: 42.9ms	remaining: 37.5ms
# 40:	learn: 4236.8970659	total: 44ms	remaining: 36.5ms
# 41:	learn: 4218.5880647	total: 45.1ms	remaining: 35.5ms
# 42:	learn: 4207.0625143	total: 46.3ms	remaining: 34.5ms
# 43:	learn: 4194.8314484	total: 47.5ms	remaining: 33.5ms
# 44:	learn: 4181.9198272	total: 48.7ms	remaining: 32.5ms
# 45:	learn: 4166.4597048	total: 49.9ms	remaining: 31.5ms
# 46:	learn: 4154.0213082	total: 51.2ms	remaining: 30.5ms
# 47:	learn: 4139.3068507	total: 52.4ms	remaining: 29.5ms
# 48:	learn: 4133.9000206	total: 53.6ms	remaining: 28.4ms
# 49:	learn: 4124.6855967	total: 54.7ms	remaining: 27.4ms
# 50:	learn: 4111.8341680	total: 55.9ms	remaining: 26.3ms
# 51:	learn: 4102.2735676	total: 57.1ms	remaining: 25.2ms
# 52:	learn: 4096.5394337	total: 58.2ms	remaining: 24.1ms
# 53:	learn: 4085.8042821	total: 59.3ms	remaining: 23.1ms
# 54:	learn: 4071.7458079	total: 60.5ms	remaining: 22ms
# 55:	learn: 4064.1329950	total: 61.7ms	remaining: 20.9ms
# 56:	learn: 4053.8148721	total: 62.9ms	remaining: 19.9ms
# 57:	learn: 4046.3148607	total: 64ms	remaining: 18.8ms
# 58:	learn: 4034.9134494	total: 65.1ms	remaining: 17.7ms
# 59:	learn: 4024.9412000	total: 66.3ms	remaining: 16.6ms
# 60:	learn: 4017.7065789	total: 67.4ms	remaining: 15.5ms
# 61:	learn: 4016.2415782	total: 67.7ms	remaining: 14.2ms
# 62:	learn: 4010.3530759	total: 68.9ms	remaining: 13.1ms
# 63:	learn: 4003.7442000	total: 70ms	remaining: 12ms
# 64:	learn: 3998.4103833	total: 71.2ms	remaining: 11ms
# 65:	learn: 3989.5973312	total: 72.3ms	remaining: 9.87ms
# 66:	learn: 3980.7433388	total: 73.5ms	remaining: 8.78ms
# 67:	learn: 3970.4908453	total: 74.6ms	remaining: 7.68ms
# 68:	learn: 3964.2131931	total: 75.7ms	remaining: 6.59ms
# 69:	learn: 3956.9148278	total: 76.9ms	remaining: 5.5ms
# 70:	learn: 3953.7012313	total: 78ms	remaining: 4.4ms
# 71:	learn: 3942.1843438	total: 79.1ms	remaining: 3.3ms
# 72:	learn: 3933.9394323	total: 80.3ms	remaining: 2.2ms
# 73:	learn: 3926.4764597	total: 81.3ms	remaining: 1.1ms
# 74:	learn: 3915.3190271	total: 82.6ms	remaining: 0us
# 0:	learn: 11373.5180986	total: 1.39ms	remaining: 103ms
# 1:	learn: 10580.3954645	total: 1.85ms	remaining: 67.6ms
# 2:	learn: 9894.3421104	total: 3.14ms	remaining: 75.4ms
# 3:	learn: 9257.6283675	total: 4.48ms	remaining: 79.5ms
# 4:	learn: 8644.3105727	total: 5.62ms	remaining: 78.7ms
# 5:	learn: 8099.9554862	total: 6.56ms	remaining: 75.5ms
# 6:	learn: 7679.2618877	total: 7.76ms	remaining: 75.4ms
# 7:	learn: 7251.7237717	total: 8.89ms	remaining: 74.5ms
# 8:	learn: 6861.0385824	total: 10ms	remaining: 73.4ms
# 9:	learn: 6608.7046847	total: 10.3ms	remaining: 66.7ms
# 10:	learn: 6335.0968000	total: 11.3ms	remaining: 65.8ms
# 11:	learn: 6065.0308571	total: 11.8ms	remaining: 61.8ms
# 12:	learn: 5904.6949312	total: 12ms	remaining: 57.5ms
# 13:	learn: 5700.0549382	total: 13.8ms	remaining: 60.1ms
# 14:	learn: 5532.1772044	total: 15.9ms	remaining: 63.6ms
# 15:	learn: 5375.2507087	total: 16.7ms	remaining: 61.6ms
# 16:	learn: 5258.4470857	total: 17.9ms	remaining: 61.2ms
# 17:	learn: 5134.2698425	total: 19.1ms	remaining: 60.6ms
# 18:	learn: 5021.3366319	total: 20.4ms	remaining: 60ms
# 19:	learn: 4916.1222691	total: 21.6ms	remaining: 59.4ms
# 20:	learn: 4840.0214179	total: 22.7ms	remaining: 58.5ms
# 21:	learn: 4762.7478445	total: 23.9ms	remaining: 57.5ms
# 22:	learn: 4697.4011474	total: 25ms	remaining: 56.6ms
# 23:	learn: 4634.6645204	total: 25.7ms	remaining: 54.6ms
# 24:	learn: 4577.7401490	total: 34.1ms	remaining: 68.2ms
# 25:	learn: 4525.7461623	total: 36.6ms	remaining: 68.9ms
# 26:	learn: 4486.3355396	total: 37.9ms	remaining: 67.4ms
# 27:	learn: 4444.9197777	total: 39.5ms	remaining: 66.2ms
# 28:	learn: 4411.1365389	total: 41.1ms	remaining: 65.1ms
# 29:	learn: 4376.2529489	total: 42.6ms	remaining: 64ms
# 30:	learn: 4348.0608680	total: 44.2ms	remaining: 62.8ms
# 31:	learn: 4323.2138466	total: 45.6ms	remaining: 61.2ms
# 32:	learn: 4297.9318818	total: 46.8ms	remaining: 59.5ms
# 33:	learn: 4271.2544142	total: 48.3ms	remaining: 58.2ms
# 34:	learn: 4250.9062942	total: 49.5ms	remaining: 56.5ms
# 35:	learn: 4234.4472549	total: 52.7ms	remaining: 57.1ms
# 36:	learn: 4216.7737130	total: 54.4ms	remaining: 55.9ms
# 37:	learn: 4204.9627721	total: 55.2ms	remaining: 53.8ms
# 38:	learn: 4187.0801440	total: 56.8ms	remaining: 52.4ms
# 39:	learn: 4175.8652215	total: 58.4ms	remaining: 51.1ms
# 40:	learn: 4166.3415798	total: 65.1ms	remaining: 54ms
# 41:	learn: 4156.2510877	total: 68.4ms	remaining: 53.7ms
# 42:	learn: 4146.0630310	total: 69.5ms	remaining: 51.7ms
# 43:	learn: 4131.8919949	total: 70.7ms	remaining: 49.8ms
# 44:	learn: 4120.1335090	total: 72ms	remaining: 48ms
# 45:	learn: 4102.9062442	total: 73.1ms	remaining: 46.1ms
# 46:	learn: 4089.4995439	total: 74.3ms	remaining: 44.2ms
# 47:	learn: 4078.0500115	total: 75.4ms	remaining: 42.4ms
# 48:	learn: 4064.1300565	total: 77.3ms	remaining: 41ms
# 49:	learn: 4056.5301041	total: 79.5ms	remaining: 39.7ms
# 50:	learn: 4046.2520101	total: 80.6ms	remaining: 37.9ms
# 51:	learn: 4033.1506858	total: 81.7ms	remaining: 36.1ms
# 52:	learn: 4032.7942609	total: 81.9ms	remaining: 34ms
# 53:	learn: 4021.8330292	total: 83ms	remaining: 32.3ms
# 54:	learn: 4014.5364562	total: 84.1ms	remaining: 30.6ms
# 55:	learn: 4002.5642512	total: 85.2ms	remaining: 28.9ms
# 56:	learn: 3996.3638987	total: 86.4ms	remaining: 27.3ms
# 57:	learn: 3984.8874178	total: 87.6ms	remaining: 25.7ms
# 58:	learn: 3970.3448036	total: 88.7ms	remaining: 24.1ms
# 59:	learn: 3956.2076677	total: 89.8ms	remaining: 22.5ms
# 60:	learn: 3950.3539163	total: 91ms	remaining: 20.9ms
# 61:	learn: 3942.4414485	total: 92.1ms	remaining: 19.3ms
# 62:	learn: 3929.3117613	total: 93.3ms	remaining: 17.8ms
# 63:	learn: 3920.0999684	total: 94.4ms	remaining: 16.2ms
# 64:	learn: 3910.3852652	total: 95.5ms	remaining: 14.7ms
# 65:	learn: 3902.8514591	total: 96.7ms	remaining: 13.2ms
# 66:	learn: 3896.1328647	total: 97.9ms	remaining: 11.7ms
# 67:	learn: 3886.8114992	total: 99ms	remaining: 10.2ms
# 68:	learn: 3879.3783166	total: 100ms	remaining: 8.7ms
# 69:	learn: 3877.5135822	total: 101ms	remaining: 7.19ms
# 70:	learn: 3867.8508501	total: 102ms	remaining: 5.73ms
# 71:	learn: 3863.0171949	total: 103ms	remaining: 4.28ms
# 72:	learn: 3855.3900511	total: 104ms	remaining: 2.85ms
# 73:	learn: 3850.0959047	total: 105ms	remaining: 1.42ms
# 74:	learn: 3839.3494734	total: 106ms	remaining: 0us
# 0:	learn: 11213.9457588	total: 1.39ms	remaining: 103ms
# 1:	learn: 10445.4121839	total: 1.83ms	remaining: 66.7ms
# 2:	learn: 9811.7564752	total: 3.1ms	remaining: 74.3ms
# 3:	learn: 9184.8931006	total: 4.23ms	remaining: 75.1ms
# 4:	learn: 8572.3024257	total: 5.36ms	remaining: 75.1ms
# 5:	learn: 8070.3007451	total: 5.68ms	remaining: 65.4ms
# 6:	learn: 7593.8791177	total: 6.81ms	remaining: 66.2ms
# 7:	learn: 7168.1698776	total: 7.95ms	remaining: 66.5ms
# 8:	learn: 6792.1199783	total: 9.16ms	remaining: 67.2ms
# 9:	learn: 6491.7691575	total: 9.47ms	remaining: 61.6ms
# 10:	learn: 6233.6472592	total: 9.82ms	remaining: 57.2ms
# 11:	learn: 5975.1954261	total: 10.7ms	remaining: 55.9ms
# 12:	learn: 5753.5413467	total: 11.8ms	remaining: 56.1ms
# 13:	learn: 5578.6147126	total: 12.9ms	remaining: 56.1ms
# 14:	learn: 5425.8823011	total: 13.3ms	remaining: 53.2ms
# 15:	learn: 5267.0993196	total: 14.4ms	remaining: 53.1ms
# 16:	learn: 5155.5053256	total: 15.5ms	remaining: 53ms
# 17:	learn: 5038.1330358	total: 16.7ms	remaining: 52.8ms
# 18:	learn: 4934.0978880	total: 17.9ms	remaining: 52.8ms
# 19:	learn: 4838.5363014	total: 18.5ms	remaining: 50.8ms
# 20:	learn: 4756.2980558	total: 19.2ms	remaining: 49.4ms
# 21:	learn: 4675.9811009	total: 20.3ms	remaining: 49ms
# 22:	learn: 4614.2513518	total: 20.9ms	remaining: 47.2ms
# 23:	learn: 4561.3008702	total: 21.9ms	remaining: 46.6ms
# 24:	learn: 4514.3549686	total: 23.1ms	remaining: 46.3ms
# 25:	learn: 4467.2833389	total: 24.2ms	remaining: 45.7ms
# 26:	learn: 4426.8422955	total: 25.4ms	remaining: 45.1ms
# 27:	learn: 4391.5795934	total: 27.1ms	remaining: 45.5ms
# 28:	learn: 4350.6583848	total: 28.7ms	remaining: 45.5ms
# 29:	learn: 4315.3816307	total: 30.3ms	remaining: 45.5ms
# 30:	learn: 4299.8260163	total: 31ms	remaining: 44ms
# 31:	learn: 4281.1590671	total: 31.7ms	remaining: 42.6ms
# 32:	learn: 4266.5967141	total: 32.2ms	remaining: 41ms
# 33:	learn: 4239.9376693	total: 33.7ms	remaining: 40.7ms
# 34:	learn: 4228.8857866	total: 35.2ms	remaining: 40.3ms
# 35:	learn: 4209.5411425	total: 36.9ms	remaining: 40ms
# 36:	learn: 4190.8607839	total: 38.3ms	remaining: 39.4ms
# 37:	learn: 4183.6606285	total: 38.9ms	remaining: 37.8ms
# 38:	learn: 4168.2429193	total: 40.3ms	remaining: 37.2ms
# 39:	learn: 4153.6460033	total: 41.8ms	remaining: 36.6ms
# 40:	learn: 4149.4849810	total: 42.2ms	remaining: 35ms
# 41:	learn: 4146.6137086	total: 42.7ms	remaining: 33.6ms
# 42:	learn: 4138.3938996	total: 43.7ms	remaining: 32.5ms
# 43:	learn: 4125.9744210	total: 45.2ms	remaining: 31.9ms
# 44:	learn: 4115.0887408	total: 46.7ms	remaining: 31.1ms
# 45:	learn: 4103.9924782	total: 54.3ms	remaining: 34.2ms
# 46:	learn: 4088.6566785	total: 55.5ms	remaining: 33ms
# 47:	learn: 4077.0447949	total: 56.8ms	remaining: 32ms
# 48:	learn: 4065.6508236	total: 58.3ms	remaining: 30.9ms
# 49:	learn: 4049.9443366	total: 64.5ms	remaining: 32.3ms
# 50:	learn: 4044.6748051	total: 65.8ms	remaining: 30.9ms
# 51:	learn: 4031.0740067	total: 66.9ms	remaining: 29.6ms
# 52:	learn: 4015.6177111	total: 73.3ms	remaining: 30.4ms
# 53:	learn: 4003.0215190	total: 74.5ms	remaining: 29ms
# 54:	learn: 4001.8131078	total: 74.8ms	remaining: 27.2ms
# 55:	learn: 3990.7989447	total: 76ms	remaining: 25.8ms
# 56:	learn: 3984.3095079	total: 81.1ms	remaining: 25.6ms
# 57:	learn: 3974.7789901	total: 82.6ms	remaining: 24.2ms
# 58:	learn: 3960.0389427	total: 83.9ms	remaining: 22.8ms
# 59:	learn: 3950.6446363	total: 89.8ms	remaining: 22.4ms
# 60:	learn: 3939.6531590	total: 91.3ms	remaining: 20.9ms
# 61:	learn: 3937.7286207	total: 91.7ms	remaining: 19.2ms
# 62:	learn: 3937.0185904	total: 92.1ms	remaining: 17.5ms
# 63:	learn: 3932.5904655	total: 93.2ms	remaining: 16ms
# 64:	learn: 3926.5666145	total: 98.4ms	remaining: 15.1ms
# 65:	learn: 3917.9496962	total: 99.9ms	remaining: 13.6ms
# 66:	learn: 3907.5733449	total: 101ms	remaining: 12.1ms
# 67:	learn: 3901.7310687	total: 107ms	remaining: 11ms
# 68:	learn: 3892.5155610	total: 108ms	remaining: 9.42ms
# 69:	learn: 3883.9775116	total: 110ms	remaining: 7.82ms
# 70:	learn: 3874.3219295	total: 111ms	remaining: 6.24ms
# 71:	learn: 3863.2783506	total: 112ms	remaining: 4.67ms
# 72:	learn: 3849.1248036	total: 118ms	remaining: 3.23ms
# 73:	learn: 3838.9807378	total: 119ms	remaining: 1.61ms
# 74:	learn: 3832.4054483	total: 127ms	remaining: 0us
# 0:	learn: 11294.9436147	total: 2.33ms	remaining: 172ms
# 1:	learn: 10525.6777724	total: 2.84ms	remaining: 104ms
# 2:	learn: 9854.2336025	total: 4.34ms	remaining: 104ms
# 3:	learn: 9226.9523893	total: 5.8ms	remaining: 103ms
# 4:	learn: 8615.1377139	total: 7.15ms	remaining: 100ms
# 5:	learn: 8114.1805710	total: 7.46ms	remaining: 85.8ms
# 6:	learn: 7640.9316562	total: 14.7ms	remaining: 143ms
# 7:	learn: 7215.9272216	total: 16.2ms	remaining: 135ms
# 8:	learn: 6850.1625091	total: 21.7ms	remaining: 159ms
# 9:	learn: 6548.8446786	total: 23.4ms	remaining: 152ms
# 10:	learn: 6266.8305597	total: 24.9ms	remaining: 145ms
# 11:	learn: 6005.6428550	total: 25.8ms	remaining: 136ms
# 12:	learn: 5811.3807659	total: 27.4ms	remaining: 131ms
# 13:	learn: 5633.5411602	total: 27.8ms	remaining: 121ms
# 14:	learn: 5474.6951863	total: 29.1ms	remaining: 116ms
# 15:	learn: 5315.4821220	total: 30.2ms	remaining: 112ms
# 16:	learn: 5176.3225476	total: 31.2ms	remaining: 107ms
# 17:	learn: 5055.2870171	total: 32.2ms	remaining: 102ms
# 18:	learn: 4963.8276587	total: 32.8ms	remaining: 96.8ms
# 19:	learn: 4890.7945686	total: 33.5ms	remaining: 92.1ms
# 20:	learn: 4812.6182709	total: 35ms	remaining: 90.1ms
# 21:	learn: 4764.1534307	total: 35.4ms	remaining: 85.4ms
# 22:	learn: 4700.9625847	total: 36.6ms	remaining: 82.7ms
# 23:	learn: 4644.4636203	total: 37.4ms	remaining: 79.5ms
# 24:	learn: 4597.3358417	total: 38.9ms	remaining: 77.7ms
# 25:	learn: 4546.1951677	total: 40.4ms	remaining: 76.2ms
# 26:	learn: 4503.0047116	total: 41.8ms	remaining: 74.4ms
# 27:	learn: 4478.6145441	total: 42.4ms	remaining: 71.2ms
# 28:	learn: 4443.3042181	total: 43.7ms	remaining: 69.3ms
# 29:	learn: 4421.4063243	total: 44.2ms	remaining: 66.3ms
# 30:	learn: 4389.3341005	total: 45.6ms	remaining: 64.7ms
# 31:	learn: 4359.5657731	total: 47ms	remaining: 63.2ms
# 32:	learn: 4344.9074519	total: 47.6ms	remaining: 60.5ms
# 33:	learn: 4319.1096261	total: 48.9ms	remaining: 59ms
# 34:	learn: 4298.1826617	total: 50ms	remaining: 57.1ms
# 35:	learn: 4273.0550728	total: 51.4ms	remaining: 55.7ms
# 36:	learn: 4252.3258745	total: 52.9ms	remaining: 54.3ms
# 37:	learn: 4235.6352129	total: 54.2ms	remaining: 52.8ms
# 38:	learn: 4229.2012517	total: 54.8ms	remaining: 50.6ms
# 39:	learn: 4212.7474950	total: 55.9ms	remaining: 48.9ms
# 40:	learn: 4211.1756724	total: 56.1ms	remaining: 46.5ms
# 41:	learn: 4194.4088173	total: 57.6ms	remaining: 45.2ms
# 42:	learn: 4172.4558573	total: 59ms	remaining: 43.9ms
# 43:	learn: 4158.9067203	total: 60.5ms	remaining: 42.6ms
# 44:	learn: 4145.3902800	total: 61.8ms	remaining: 41.2ms
# 45:	learn: 4127.8531831	total: 62.9ms	remaining: 39.6ms
# 46:	learn: 4114.1797405	total: 64ms	remaining: 38.1ms
# 47:	learn: 4101.5706710	total: 65.2ms	remaining: 36.7ms
# 48:	learn: 4098.5706430	total: 65.7ms	remaining: 34.9ms
# 49:	learn: 4089.5242628	total: 67.2ms	remaining: 33.6ms
# 50:	learn: 4073.2002498	total: 68.8ms	remaining: 32.4ms
# 51:	learn: 4062.6412225	total: 70.3ms	remaining: 31.1ms
# 52:	learn: 4053.4239638	total: 71.6ms	remaining: 29.7ms
# 53:	learn: 4038.3884483	total: 72.7ms	remaining: 28.3ms
# 54:	learn: 4029.0529617	total: 73.9ms	remaining: 26.9ms
# 55:	learn: 4021.1248268	total: 75ms	remaining: 25.4ms
# 56:	learn: 4009.7750779	total: 76.4ms	remaining: 24.1ms
# 57:	learn: 4001.9523815	total: 77.9ms	remaining: 22.8ms
# 58:	learn: 3992.6270782	total: 79.2ms	remaining: 21.5ms
# 59:	learn: 3987.8776412	total: 80.5ms	remaining: 20.1ms
# 60:	learn: 3970.9662108	total: 81.6ms	remaining: 18.7ms
# 61:	learn: 3959.4128734	total: 83ms	remaining: 17.4ms
# 62:	learn: 3952.9786787	total: 84.3ms	remaining: 16.1ms
# 63:	learn: 3948.9810582	total: 85.2ms	remaining: 14.7ms
# 64:	learn: 3935.3590273	total: 86.8ms	remaining: 13.3ms
# 65:	learn: 3927.2338888	total: 88.3ms	remaining: 12ms
# 66:	learn: 3918.5338274	total: 89.9ms	remaining: 10.7ms
# 67:	learn: 3911.1554999	total: 91.4ms	remaining: 9.41ms
# 68:	learn: 3902.9898702	total: 92.8ms	remaining: 8.07ms
# 69:	learn: 3892.6212875	total: 94.4ms	remaining: 6.74ms
# 70:	learn: 3880.9809892	total: 95.8ms	remaining: 5.4ms
# 71:	learn: 3871.0685910	total: 97.1ms	remaining: 4.04ms
# 72:	learn: 3867.1286829	total: 98.4ms	remaining: 2.69ms
# 73:	learn: 3856.2632573	total: 99.6ms	remaining: 1.34ms
# 74:	learn: 3847.1139686	total: 101ms	remaining: 0us
# 0:	learn: 11374.6435625	total: 1.35ms	remaining: 99.8ms
# 1:	learn: 10576.0442431	total: 11.9ms	remaining: 433ms
# 2:	learn: 9919.9522347	total: 19.1ms	remaining: 458ms
# 3:	learn: 9272.3399484	total: 31.7ms	remaining: 563ms
# 4:	learn: 8652.2774262	total: 59.1ms	remaining: 828ms
# 5:	learn: 8133.5897631	total: 59.7ms	remaining: 687ms
# 6:	learn: 7636.6481901	total: 96.1ms	remaining: 934ms
# 7:	learn: 7202.1550898	total: 105ms	remaining: 877ms
# 8:	learn: 6820.4495450	total: 121ms	remaining: 886ms
# 9:	learn: 6500.6574282	total: 174ms	remaining: 1.13s
# 10:	learn: 6191.4738494	total: 183ms	remaining: 1.07s
# 11:	learn: 5928.2528979	total: 196ms	remaining: 1.03s
# 12:	learn: 5714.5967234	total: 198ms	remaining: 944ms
# 13:	learn: 5511.8600222	total: 199ms	remaining: 868ms
# 14:	learn: 5357.5309158	total: 202ms	remaining: 807ms
# 15:	learn: 5210.4797346	total: 203ms	remaining: 749ms
# 16:	learn: 5074.9701153	total: 208ms	remaining: 709ms
# 17:	learn: 4950.8869513	total: 209ms	remaining: 663ms
# 18:	learn: 4844.0659105	total: 218ms	remaining: 641ms
# 19:	learn: 4766.3962223	total: 218ms	remaining: 600ms
# 20:	learn: 4687.5242123	total: 225ms	remaining: 579ms
# 21:	learn: 4620.7714693	total: 227ms	remaining: 546ms
# 22:	learn: 4562.3448234	total: 231ms	remaining: 523ms
# 23:	learn: 4519.8643028	total: 237ms	remaining: 504ms
# 24:	learn: 4476.2228775	total: 239ms	remaining: 477ms
# 25:	learn: 4437.2180846	total: 251ms	remaining: 474ms
# 26:	learn: 4396.7570312	total: 255ms	remaining: 454ms
# 27:	learn: 4365.1534349	total: 257ms	remaining: 432ms
# 28:	learn: 4334.2338651	total: 259ms	remaining: 411ms
# 29:	learn: 4315.6422472	total: 259ms	remaining: 389ms
# 30:	learn: 4277.8788800	total: 260ms	remaining: 370ms
# 31:	learn: 4254.8391376	total: 262ms	remaining: 352ms
# 32:	learn: 4230.9764322	total: 263ms	remaining: 335ms
# 33:	learn: 4211.7430891	total: 264ms	remaining: 318ms
# 34:	learn: 4188.4186480	total: 265ms	remaining: 303ms
# 35:	learn: 4165.3478998	total: 266ms	remaining: 289ms
# 36:	learn: 4150.7905859	total: 268ms	remaining: 275ms
# 37:	learn: 4130.8749472	total: 269ms	remaining: 262ms
# 38:	learn: 4111.2388215	total: 270ms	remaining: 249ms
# 39:	learn: 4095.6043100	total: 271ms	remaining: 237ms
# 40:	learn: 4075.2824574	total: 272ms	remaining: 226ms
# 41:	learn: 4072.3379947	total: 272ms	remaining: 214ms
# 42:	learn: 4056.0339339	total: 274ms	remaining: 204ms
# 43:	learn: 4042.9933728	total: 275ms	remaining: 194ms
# 44:	learn: 4031.0961949	total: 276ms	remaining: 184ms
# 45:	learn: 4009.8808184	total: 277ms	remaining: 175ms
# 46:	learn: 3995.4797174	total: 278ms	remaining: 166ms
# 47:	learn: 3989.0236256	total: 279ms	remaining: 157ms
# 48:	learn: 3982.6886812	total: 280ms	remaining: 149ms
# 49:	learn: 3969.8740134	total: 281ms	remaining: 141ms
# 50:	learn: 3958.2184577	total: 283ms	remaining: 133ms
# 51:	learn: 3946.3616598	total: 284ms	remaining: 125ms
# 52:	learn: 3945.5170081	total: 284ms	remaining: 118ms
# 53:	learn: 3927.1765529	total: 285ms	remaining: 111ms
# 54:	learn: 3920.6211470	total: 286ms	remaining: 104ms
# 55:	learn: 3916.3960307	total: 287ms	remaining: 97.5ms
# 56:	learn: 3908.7722869	total: 289ms	remaining: 91.1ms
# 57:	learn: 3900.4562298	total: 290ms	remaining: 84.9ms
# 58:	learn: 3893.8202157	total: 291ms	remaining: 78.9ms
# 59:	learn: 3884.5808880	total: 292ms	remaining: 73ms
# 60:	learn: 3877.7761382	total: 293ms	remaining: 67.2ms
# 61:	learn: 3871.5775148	total: 294ms	remaining: 61.7ms
# 62:	learn: 3859.8052799	total: 295ms	remaining: 56.2ms
# 63:	learn: 3850.1650192	total: 296ms	remaining: 50.9ms
# 64:	learn: 3845.1520976	total: 298ms	remaining: 45.8ms
# 65:	learn: 3833.4028643	total: 299ms	remaining: 40.7ms
# 66:	learn: 3827.0471849	total: 300ms	remaining: 35.8ms
# 67:	learn: 3820.2689693	total: 301ms	remaining: 31ms
# 68:	learn: 3811.8338304	total: 302ms	remaining: 26.3ms
# 69:	learn: 3800.5268149	total: 303ms	remaining: 21.7ms
# 70:	learn: 3794.2038579	total: 304ms	remaining: 17.1ms
# 71:	learn: 3784.2108554	total: 305ms	remaining: 12.7ms
# 72:	learn: 3773.1016180	total: 307ms	remaining: 8.4ms
# 73:	learn: 3769.5859531	total: 308ms	remaining: 4.16ms
# 74:	learn: 3767.5435193	total: 308ms	remaining: 0us
# 0:	learn: 11409.7004041	total: 1.29ms	remaining: 95.4ms
# 1:	learn: 10602.3815040	total: 1.73ms	remaining: 63.3ms
# 2:	learn: 9908.9222164	total: 2.96ms	remaining: 71.1ms
# 3:	learn: 9273.0380766	total: 4.13ms	remaining: 73.2ms
# 4:	learn: 8655.2352441	total: 5.25ms	remaining: 73.4ms
# 5:	learn: 8141.9156180	total: 5.58ms	remaining: 64.1ms
# 6:	learn: 7670.4319655	total: 6.85ms	remaining: 66.5ms
# 7:	learn: 7240.2440919	total: 8.02ms	remaining: 67.1ms
# 8:	learn: 6857.8873674	total: 9.12ms	remaining: 66.9ms
# 9:	learn: 6542.8246372	total: 9.43ms	remaining: 61.3ms
# 10:	learn: 6279.2844645	total: 9.74ms	remaining: 56.7ms
# 11:	learn: 6014.3584690	total: 10.5ms	remaining: 55.1ms
# 12:	learn: 5788.6274893	total: 11.6ms	remaining: 55.4ms
# 13:	learn: 5619.9148526	total: 12.7ms	remaining: 55.4ms
# 14:	learn: 5463.8490994	total: 13.1ms	remaining: 52.5ms
# 15:	learn: 5299.1054853	total: 14.3ms	remaining: 52.9ms
# 16:	learn: 5170.9299437	total: 15.6ms	remaining: 53.1ms
# 17:	learn: 5062.5391570	total: 16.7ms	remaining: 52.8ms
# 18:	learn: 4956.5437652	total: 17.8ms	remaining: 52.6ms
# 19:	learn: 4859.6201852	total: 18.4ms	remaining: 50.5ms
# 20:	learn: 4812.4999781	total: 18.7ms	remaining: 48.1ms
# 21:	learn: 4741.1630567	total: 19.9ms	remaining: 47.9ms
# 22:	learn: 4680.3067046	total: 21ms	remaining: 47.6ms
# 23:	learn: 4619.8884995	total: 22.2ms	remaining: 47.1ms
# 24:	learn: 4568.4732396	total: 23.3ms	remaining: 46.5ms
# 25:	learn: 4521.1191056	total: 24.4ms	remaining: 46ms
# 26:	learn: 4481.1213221	total: 25.7ms	remaining: 45.7ms
# 27:	learn: 4446.8564081	total: 26.4ms	remaining: 44.4ms
# 28:	learn: 4412.5604811	total: 27.6ms	remaining: 43.7ms
# 29:	learn: 4380.6707676	total: 28.7ms	remaining: 43ms
# 30:	learn: 4354.5772346	total: 29.8ms	remaining: 42.2ms
# 31:	learn: 4334.6175598	total: 30.9ms	remaining: 41.5ms
# 32:	learn: 4312.0444615	total: 32ms	remaining: 40.7ms
# 33:	learn: 4287.0928868	total: 33.3ms	remaining: 40.1ms
# 34:	learn: 4281.4427069	total: 33.6ms	remaining: 38.4ms
# 35:	learn: 4258.2525974	total: 34.7ms	remaining: 37.6ms
# 36:	learn: 4241.3644909	total: 35.8ms	remaining: 36.7ms
# 37:	learn: 4238.7132779	total: 36ms	remaining: 35.1ms
# 38:	learn: 4220.2624805	total: 37.3ms	remaining: 34.5ms
# 39:	learn: 4206.3325179	total: 38.4ms	remaining: 33.6ms
# 40:	learn: 4190.4411180	total: 39.6ms	remaining: 32.8ms
# 41:	learn: 4173.0473266	total: 40.7ms	remaining: 32ms
# 42:	learn: 4159.3013766	total: 41.9ms	remaining: 31.2ms
# 43:	learn: 4137.9145023	total: 44.4ms	remaining: 31.3ms
# 44:	learn: 4128.2184307	total: 46.2ms	remaining: 30.8ms
# 45:	learn: 4108.3302342	total: 48.9ms	remaining: 30.8ms
# 46:	learn: 4094.4640609	total: 51.9ms	remaining: 30.9ms
# 47:	learn: 4079.8828908	total: 53.3ms	remaining: 30ms
# 48:	learn: 4071.4818011	total: 54.7ms	remaining: 29ms
# 49:	learn: 4055.5145072	total: 55.9ms	remaining: 28ms
# 50:	learn: 4044.9377079	total: 57.2ms	remaining: 26.9ms
# 51:	learn: 4032.7188955	total: 58.5ms	remaining: 25.9ms
# 52:	learn: 4019.8176879	total: 59.6ms	remaining: 24.7ms
# 53:	learn: 4011.7672848	total: 60.7ms	remaining: 23.6ms
# 54:	learn: 4000.3744603	total: 61.9ms	remaining: 22.5ms
# 55:	learn: 3988.2113773	total: 63ms	remaining: 21.4ms
# 56:	learn: 3976.6470326	total: 64.2ms	remaining: 20.3ms
# 57:	learn: 3971.3719379	total: 64.9ms	remaining: 19ms
# 58:	learn: 3964.3145171	total: 66ms	remaining: 17.9ms
# 59:	learn: 3954.3732480	total: 67.1ms	remaining: 16.8ms
# 60:	learn: 3952.7566202	total: 67.5ms	remaining: 15.5ms
# 61:	learn: 3940.6001441	total: 68.7ms	remaining: 14.4ms
# 62:	learn: 3938.8764853	total: 69.4ms	remaining: 13.2ms
# 63:	learn: 3926.8072798	total: 70.6ms	remaining: 12.1ms
# 64:	learn: 3919.1647746	total: 71.9ms	remaining: 11.1ms
# 65:	learn: 3908.1585397	total: 73ms	remaining: 9.95ms
# 66:	learn: 3898.6873854	total: 74.1ms	remaining: 8.85ms
# 67:	learn: 3885.5402357	total: 75.2ms	remaining: 7.74ms
# 68:	learn: 3879.1308924	total: 76.3ms	remaining: 6.64ms
# 69:	learn: 3874.2649693	total: 77.5ms	remaining: 5.53ms
# 70:	learn: 3866.0730717	total: 78.6ms	remaining: 4.43ms
# 71:	learn: 3859.5123764	total: 79.8ms	remaining: 3.32ms
# 72:	learn: 3852.0456046	total: 80.9ms	remaining: 2.22ms
# 73:	learn: 3849.1472282	total: 81.6ms	remaining: 1.1ms
# 74:	learn: 3841.1011026	total: 82.7ms	remaining: 0us
# 0:	learn: 11220.1314559	total: 1.32ms	remaining: 97.4ms
# 1:	learn: 10465.4585289	total: 1.81ms	remaining: 66.1ms
# 2:	learn: 9797.4253647	total: 3.04ms	remaining: 72.9ms
# 3:	learn: 9172.4641104	total: 4.17ms	remaining: 74ms
# 4:	learn: 8603.1885475	total: 5.28ms	remaining: 73.9ms
# 5:	learn: 8104.0298816	total: 5.61ms	remaining: 64.5ms
# 6:	learn: 7642.5698418	total: 6.7ms	remaining: 65ms
# 7:	learn: 7217.3748476	total: 7.81ms	remaining: 65.4ms
# 8:	learn: 6842.1834433	total: 8.89ms	remaining: 65.2ms
# 9:	learn: 6559.0398037	total: 10.1ms	remaining: 65.5ms
# 10:	learn: 6273.8952597	total: 11.2ms	remaining: 64.9ms
# 11:	learn: 6002.9995527	total: 11.9ms	remaining: 62.4ms
# 12:	learn: 5789.6993369	total: 12.6ms	remaining: 60.2ms
# 13:	learn: 5588.8550647	total: 13.8ms	remaining: 59.9ms
# 14:	learn: 5404.9889516	total: 14.9ms	remaining: 59.6ms
# 15:	learn: 5269.1604330	total: 16ms	remaining: 58.9ms
# 16:	learn: 5134.7476956	total: 17.1ms	remaining: 58.2ms
# 17:	learn: 5019.6771575	total: 18.1ms	remaining: 57.5ms
# 18:	learn: 4920.6386485	total: 18.8ms	remaining: 55.3ms
# 19:	learn: 4835.0432157	total: 19.9ms	remaining: 54.6ms
# 20:	learn: 4759.7874426	total: 21.1ms	remaining: 54.2ms
# 21:	learn: 4690.6130190	total: 22.2ms	remaining: 53.5ms
# 22:	learn: 4629.3651755	total: 23.4ms	remaining: 52.9ms
# 23:	learn: 4588.8880977	total: 23.9ms	remaining: 50.9ms
# 24:	learn: 4547.2647234	total: 24.7ms	remaining: 49.3ms
# 25:	learn: 4500.7453576	total: 26.3ms	remaining: 49.6ms
# 26:	learn: 4462.8173358	total: 27.6ms	remaining: 49ms
# 27:	learn: 4422.4115822	total: 28.9ms	remaining: 48.5ms
# 28:	learn: 4391.0784041	total: 32.8ms	remaining: 52.1ms
# 29:	learn: 4361.2783759	total: 34ms	remaining: 51ms
# 30:	learn: 4352.1105761	total: 34.3ms	remaining: 48.6ms
# 31:	learn: 4323.5111725	total: 35.5ms	remaining: 47.7ms
# 32:	learn: 4288.3922475	total: 36.7ms	remaining: 46.7ms
# 33:	learn: 4267.3055615	total: 37.9ms	remaining: 45.6ms
# 34:	learn: 4241.8296111	total: 39ms	remaining: 44.6ms
# 35:	learn: 4224.1828805	total: 40.1ms	remaining: 43.4ms
# 36:	learn: 4204.5322541	total: 41.2ms	remaining: 42.3ms
# 37:	learn: 4186.7140358	total: 42.3ms	remaining: 41.2ms
# 38:	learn: 4167.1133677	total: 43.4ms	remaining: 40.1ms
# 39:	learn: 4161.6152733	total: 43.8ms	remaining: 38.3ms
# 40:	learn: 4143.2015502	total: 44.9ms	remaining: 37.2ms
# 41:	learn: 4128.1663730	total: 46ms	remaining: 36.2ms
# 42:	learn: 4114.4635238	total: 47.1ms	remaining: 35.1ms
# 43:	learn: 4097.1998108	total: 48.2ms	remaining: 33.9ms
# 44:	learn: 4081.4334405	total: 49.4ms	remaining: 32.9ms
# 45:	learn: 4062.4240526	total: 50.6ms	remaining: 31.9ms
# 46:	learn: 4050.6857926	total: 51.7ms	remaining: 30.8ms
# 47:	learn: 4036.4275931	total: 52.9ms	remaining: 29.7ms
# 48:	learn: 4023.2076026	total: 54ms	remaining: 28.7ms
# 49:	learn: 4015.2292684	total: 55.1ms	remaining: 27.5ms
# 50:	learn: 4010.4342987	total: 55.8ms	remaining: 26.3ms
# 51:	learn: 3998.7278643	total: 57ms	remaining: 25.2ms
# 52:	learn: 3983.0035781	total: 58.1ms	remaining: 24.1ms
# 53:	learn: 3973.0946584	total: 59.2ms	remaining: 23ms
# 54:	learn: 3964.9119509	total: 60.4ms	remaining: 22ms
# 55:	learn: 3951.4847196	total: 61.6ms	remaining: 20.9ms
# 56:	learn: 3942.1034738	total: 62.9ms	remaining: 19.9ms
# 57:	learn: 3928.2266430	total: 67.9ms	remaining: 19.9ms
# 58:	learn: 3918.0712711	total: 69.1ms	remaining: 18.7ms
# 59:	learn: 3906.7856591	total: 70.3ms	remaining: 17.6ms
# 60:	learn: 3899.5255646	total: 71.8ms	remaining: 16.5ms
# 61:	learn: 3890.0331289	total: 73.4ms	remaining: 15.4ms
# 62:	learn: 3880.6292056	total: 75ms	remaining: 14.3ms
# 63:	learn: 3876.9916892	total: 76.6ms	remaining: 13.2ms
# 64:	learn: 3869.2668998	total: 78.1ms	remaining: 12ms
# 65:	learn: 3859.4997249	total: 79.6ms	remaining: 10.9ms
# 66:	learn: 3846.8917706	total: 85.7ms	remaining: 10.2ms
# 67:	learn: 3842.6042841	total: 87.3ms	remaining: 8.98ms
# 68:	learn: 3826.1829497	total: 88.9ms	remaining: 7.73ms
# 69:	learn: 3814.2515309	total: 94.8ms	remaining: 6.77ms
# 70:	learn: 3803.2115351	total: 96.5ms	remaining: 5.44ms
# 71:	learn: 3790.1234127	total: 101ms	remaining: 4.19ms
# 72:	learn: 3776.1445263	total: 102ms	remaining: 2.79ms
# 73:	learn: 3761.7841362	total: 103ms	remaining: 1.39ms
# 74:	learn: 3758.2740121	total: 104ms	remaining: 0us
# 0:	learn: 11280.6995662	total: 2.11ms	remaining: 156ms
# 1:	learn: 10509.3179840	total: 2.66ms	remaining: 97.1ms
# 2:	learn: 9829.8766960	total: 7.79ms	remaining: 187ms
# 3:	learn: 9196.2897644	total: 16.6ms	remaining: 294ms
# 4:	learn: 8585.2631481	total: 20.1ms	remaining: 281ms
# 5:	learn: 8081.3268638	total: 20.6ms	remaining: 237ms
# 6:	learn: 7603.3732273	total: 22ms	remaining: 214ms
# 7:	learn: 7181.1403159	total: 23.4ms	remaining: 196ms
# 8:	learn: 6809.0112621	total: 30ms	remaining: 220ms
# 9:	learn: 6517.3859531	total: 39.3ms	remaining: 256ms
# 10:	learn: 6212.5265455	total: 40.8ms	remaining: 238ms
# 11:	learn: 5949.9211274	total: 41.8ms	remaining: 219ms
# 12:	learn: 5731.8852061	total: 42.8ms	remaining: 204ms
# 13:	learn: 5536.5180440	total: 48.3ms	remaining: 210ms
# 14:	learn: 5370.8482370	total: 49.7ms	remaining: 199ms
# 15:	learn: 5219.5467277	total: 59.1ms	remaining: 218ms
# 16:	learn: 5088.6754245	total: 60.6ms	remaining: 207ms
# 17:	learn: 4981.7231661	total: 61.9ms	remaining: 196ms
# 18:	learn: 4898.4242843	total: 62.3ms	remaining: 184ms
# 19:	learn: 4806.1776307	total: 65.1ms	remaining: 179ms
# 20:	learn: 4731.7752139	total: 66.4ms	remaining: 171ms
# 21:	learn: 4666.6219125	total: 67.7ms	remaining: 163ms
# 22:	learn: 4607.8553245	total: 69ms	remaining: 156ms
# 23:	learn: 4557.9580302	total: 75.1ms	remaining: 160ms
# 24:	learn: 4508.7354004	total: 76.5ms	remaining: 153ms
# 25:	learn: 4464.6406786	total: 77.8ms	remaining: 147ms
# 26:	learn: 4424.1638985	total: 85ms	remaining: 151ms
# 27:	learn: 4401.0754309	total: 86.8ms	remaining: 146ms
# 28:	learn: 4368.6688381	total: 95.8ms	remaining: 152ms
# 29:	learn: 4345.8673414	total: 96.8ms	remaining: 145ms
# 30:	learn: 4310.1153434	total: 98.2ms	remaining: 139ms
# 31:	learn: 4286.5441080	total: 105ms	remaining: 140ms
# 32:	learn: 4265.4167540	total: 106ms	remaining: 135ms
# 33:	learn: 4246.3478348	total: 107ms	remaining: 129ms
# 34:	learn: 4225.4826422	total: 109ms	remaining: 124ms
# 35:	learn: 4203.3974337	total: 115ms	remaining: 124ms
# 36:	learn: 4188.4355688	total: 116ms	remaining: 119ms
# 37:	learn: 4168.2740911	total: 118ms	remaining: 114ms
# 38:	learn: 4148.3083862	total: 120ms	remaining: 111ms
# 39:	learn: 4129.9042899	total: 121ms	remaining: 106ms
# 40:	learn: 4118.5017822	total: 122ms	remaining: 101ms
# 41:	learn: 4115.3102090	total: 123ms	remaining: 96.4ms
# 42:	learn: 4099.8757713	total: 124ms	remaining: 92.2ms
# 43:	learn: 4089.1757167	total: 125ms	remaining: 88.1ms
# 44:	learn: 4070.9176647	total: 126ms	remaining: 84.2ms
# 45:	learn: 4063.7341811	total: 127ms	remaining: 80.3ms
# 46:	learn: 4047.3605295	total: 129ms	remaining: 76.7ms
# 47:	learn: 4036.4255090	total: 130ms	remaining: 73ms
# 48:	learn: 4025.0478462	total: 131ms	remaining: 69.5ms
# 49:	learn: 4019.8407158	total: 132ms	remaining: 66ms
# 50:	learn: 4012.0462775	total: 133ms	remaining: 62.7ms
# 51:	learn: 4006.4878975	total: 134ms	remaining: 59.4ms
# 52:	learn: 4002.1249325	total: 136ms	remaining: 56.3ms
# 53:	learn: 3991.9237559	total: 137ms	remaining: 53.1ms
# 54:	learn: 3983.5038305	total: 138ms	remaining: 50.1ms
# 55:	learn: 3975.5437915	total: 139ms	remaining: 47.1ms
# 56:	learn: 3965.4092701	total: 140ms	remaining: 44.2ms
# 57:	learn: 3957.7933693	total: 141ms	remaining: 41.4ms
# 58:	learn: 3948.7698946	total: 142ms	remaining: 38.6ms
# 59:	learn: 3936.6198169	total: 144ms	remaining: 35.9ms
# 60:	learn: 3928.2479306	total: 145ms	remaining: 33.2ms
# 61:	learn: 3923.8737788	total: 146ms	remaining: 30.6ms
# 62:	learn: 3918.7110859	total: 147ms	remaining: 28ms
# 63:	learn: 3908.0028463	total: 148ms	remaining: 25.5ms
# 64:	learn: 3895.8890687	total: 149ms	remaining: 23ms
# 65:	learn: 3886.6893756	total: 151ms	remaining: 20.5ms
# 66:	learn: 3878.1008850	total: 152ms	remaining: 18.1ms
# 67:	learn: 3874.3045336	total: 153ms	remaining: 15.7ms
# 68:	learn: 3867.4688524	total: 154ms	remaining: 13.4ms
# 69:	learn: 3861.4751162	total: 155ms	remaining: 11.1ms
# 70:	learn: 3858.0511415	total: 156ms	remaining: 8.8ms
# 71:	learn: 3855.1611444	total: 157ms	remaining: 6.54ms
# 72:	learn: 3848.8129852	total: 158ms	remaining: 4.33ms
# 73:	learn: 3839.8871917	total: 159ms	remaining: 2.15ms
# 74:	learn: 3823.4914725	total: 160ms	remaining: 0us
# 0:	learn: 11345.0976851	total: 2.44ms	remaining: 181ms
# 1:	learn: 10560.2574517	total: 3.15ms	remaining: 115ms
# 2:	learn: 9877.3286512	total: 5.62ms	remaining: 135ms
# 3:	learn: 9248.6421497	total: 8.53ms	remaining: 151ms
# 4:	learn: 8630.2810667	total: 10.8ms	remaining: 152ms
# 5:	learn: 8090.6576519	total: 11.7ms	remaining: 135ms
# 6:	learn: 7669.4630564	total: 13.1ms	remaining: 127ms
# 7:	learn: 7222.7793511	total: 14.3ms	remaining: 119ms
# 8:	learn: 6847.8771195	total: 15.5ms	remaining: 113ms
# 9:	learn: 6498.4807959	total: 16.6ms	remaining: 108ms
# 10:	learn: 6235.5038255	total: 17ms	remaining: 99ms
# 11:	learn: 5984.3604814	total: 18.4ms	remaining: 96.4ms
# 12:	learn: 5791.7497644	total: 19.5ms	remaining: 93ms
# 13:	learn: 5605.8293688	total: 19.8ms	remaining: 86.3ms
# 14:	learn: 5444.2191834	total: 21ms	remaining: 84.1ms
# 15:	learn: 5285.0696260	total: 22.3ms	remaining: 82.1ms
# 16:	learn: 5141.3227636	total: 23ms	remaining: 78.5ms
# 17:	learn: 5010.0039567	total: 23.8ms	remaining: 75.5ms
# 18:	learn: 4913.4996744	total: 24.4ms	remaining: 71.9ms
# 19:	learn: 4843.3519148	total: 24.8ms	remaining: 68.3ms
# 20:	learn: 4763.8331261	total: 26ms	remaining: 66.8ms
# 21:	learn: 4714.3434889	total: 26.3ms	remaining: 63.4ms
# 22:	learn: 4647.7690275	total: 27.6ms	remaining: 62.3ms
# 23:	learn: 4595.8262190	total: 28.1ms	remaining: 59.8ms
# 24:	learn: 4544.5450937	total: 29.2ms	remaining: 58.4ms
# 25:	learn: 4516.6030772	total: 29.7ms	remaining: 55.9ms
# 26:	learn: 4472.2443849	total: 30.8ms	remaining: 54.8ms
# 27:	learn: 4434.4404436	total: 32ms	remaining: 53.8ms
# 28:	learn: 4404.0581143	total: 33.2ms	remaining: 52.7ms
# 29:	learn: 4367.2217440	total: 34.3ms	remaining: 51.5ms
# 30:	learn: 4335.7642658	total: 35.4ms	remaining: 50.3ms
# 31:	learn: 4304.6123034	total: 36.5ms	remaining: 49.1ms
# 32:	learn: 4289.3568431	total: 36.9ms	remaining: 47ms
# 33:	learn: 4267.5550896	total: 38ms	remaining: 45.8ms
# 34:	learn: 4248.8690434	total: 39.1ms	remaining: 44.7ms
# 35:	learn: 4227.4625628	total: 40.2ms	remaining: 43.6ms
# 36:	learn: 4209.6902000	total: 41.3ms	remaining: 42.5ms
# 37:	learn: 4191.5985116	total: 42.6ms	remaining: 41.4ms
# 38:	learn: 4167.5066262	total: 43.6ms	remaining: 40.3ms
# 39:	learn: 4146.7955896	total: 44.8ms	remaining: 39.2ms
# 40:	learn: 4133.4533953	total: 46ms	remaining: 38.1ms
# 41:	learn: 4118.6920764	total: 47.1ms	remaining: 37ms
# 42:	learn: 4100.2504532	total: 48.2ms	remaining: 35.9ms
# 43:	learn: 4092.4039057	total: 49.3ms	remaining: 34.7ms
# 44:	learn: 4082.0008704	total: 50.4ms	remaining: 33.6ms
# 45:	learn: 4066.2656732	total: 51.5ms	remaining: 32.5ms
# 46:	learn: 4052.2035744	total: 52.6ms	remaining: 31.3ms
# 47:	learn: 4039.9199900	total: 53.8ms	remaining: 30.3ms
# 48:	learn: 4025.8180194	total: 55ms	remaining: 29.2ms
# 49:	learn: 4014.7252760	total: 56.1ms	remaining: 28.1ms
# 50:	learn: 3999.5752992	total: 57.3ms	remaining: 27ms
# 51:	learn: 3983.3896484	total: 58.5ms	remaining: 25.9ms
# 52:	learn: 3962.8683558	total: 59.7ms	remaining: 24.8ms
# 53:	learn: 3955.9124609	total: 60.9ms	remaining: 23.7ms
# 54:	learn: 3951.0408523	total: 62ms	remaining: 22.5ms
# 55:	learn: 3941.3271459	total: 63.2ms	remaining: 21.4ms
# 56:	learn: 3928.9506921	total: 64.3ms	remaining: 20.3ms
# 57:	learn: 3917.6684441	total: 65.4ms	remaining: 19.2ms
# 58:	learn: 3901.9247800	total: 66.5ms	remaining: 18ms
# 59:	learn: 3900.0621198	total: 67ms	remaining: 16.7ms
# 60:	learn: 3890.4996313	total: 68.2ms	remaining: 15.6ms
# 61:	learn: 3876.9609222	total: 69.3ms	remaining: 14.5ms
# 62:	learn: 3862.3217102	total: 70.4ms	remaining: 13.4ms
# 63:	learn: 3856.2613497	total: 71.5ms	remaining: 12.3ms
# 64:	learn: 3846.1314542	total: 72.6ms	remaining: 11.2ms
# 65:	learn: 3837.4349418	total: 73.8ms	remaining: 10.1ms
# 66:	learn: 3835.5464884	total: 74.2ms	remaining: 8.86ms
# 67:	learn: 3826.9559782	total: 75.3ms	remaining: 7.75ms
# 68:	learn: 3823.2071863	total: 75.7ms	remaining: 6.58ms
# 69:	learn: 3815.9248191	total: 76.7ms	remaining: 5.48ms
# 70:	learn: 3808.7868828	total: 77.9ms	remaining: 4.39ms
# 71:	learn: 3804.0581526	total: 79ms	remaining: 3.29ms
# 72:	learn: 3795.5118123	total: 80.2ms	remaining: 2.2ms
# 73:	learn: 3786.5393061	total: 81.4ms	remaining: 1.1ms
# 74:	learn: 3778.5436306	total: 82.5ms	remaining: 0us
# 0:	learn: 11077.5496371	total: 1.36ms	remaining: 100ms
# 1:	learn: 10307.4336328	total: 1.79ms	remaining: 65.5ms
# 2:	learn: 9663.6573721	total: 3.03ms	remaining: 72.8ms
# 3:	learn: 9034.7304093	total: 4.19ms	remaining: 74.3ms
# 4:	learn: 8424.1371033	total: 5.31ms	remaining: 74.4ms
# 5:	learn: 7914.0547877	total: 5.63ms	remaining: 64.8ms
# 6:	learn: 7448.5944793	total: 6.74ms	remaining: 65.5ms
# 7:	learn: 7023.9301857	total: 7.87ms	remaining: 65.9ms
# 8:	learn: 6627.7232985	total: 8.97ms	remaining: 65.8ms
# 9:	learn: 6316.3492787	total: 10.2ms	remaining: 66.1ms
# 10:	learn: 6013.2687812	total: 11.3ms	remaining: 65.5ms
# 11:	learn: 5751.2482750	total: 12ms	remaining: 63.1ms
# 12:	learn: 5543.1913472	total: 12.8ms	remaining: 61.2ms
# 13:	learn: 5346.6992233	total: 14ms	remaining: 61ms
# 14:	learn: 5164.7174178	total: 15.1ms	remaining: 60.5ms
# 15:	learn: 5012.9915938	total: 16.3ms	remaining: 59.9ms
# 16:	learn: 4872.1173105	total: 16.8ms	remaining: 57.4ms
# 17:	learn: 4760.6319793	total: 17.9ms	remaining: 56.8ms
# 18:	learn: 4656.9253239	total: 18.5ms	remaining: 54.4ms
# 19:	learn: 4567.7266091	total: 18.9ms	remaining: 52ms
# 20:	learn: 4493.7081443	total: 20.1ms	remaining: 51.6ms
# 21:	learn: 4430.8538810	total: 21.2ms	remaining: 51ms
# 22:	learn: 4372.1369092	total: 22.4ms	remaining: 50.7ms
# 23:	learn: 4327.6403429	total: 23.5ms	remaining: 50ms
# 24:	learn: 4281.5776573	total: 24.6ms	remaining: 49.2ms
# 25:	learn: 4240.9192958	total: 25.7ms	remaining: 48.4ms
# 26:	learn: 4201.4766589	total: 26.8ms	remaining: 47.7ms
# 27:	learn: 4174.4695016	total: 27.6ms	remaining: 46.4ms
# 28:	learn: 4148.0669593	total: 28.9ms	remaining: 45.8ms
# 29:	learn: 4129.2643829	total: 29.3ms	remaining: 43.9ms
# 30:	learn: 4098.4056786	total: 30.4ms	remaining: 43.1ms
# 31:	learn: 4072.9843002	total: 31.5ms	remaining: 42.4ms
# 32:	learn: 4062.5151212	total: 31.9ms	remaining: 40.6ms
# 33:	learn: 4041.3930260	total: 33ms	remaining: 39.9ms
# 34:	learn: 4024.4033644	total: 34.3ms	remaining: 39.2ms
# 35:	learn: 4010.7371802	total: 35.4ms	remaining: 38.3ms
# 36:	learn: 3986.4199233	total: 36.5ms	remaining: 37.5ms
# 37:	learn: 3978.1649409	total: 36.9ms	remaining: 35.9ms
# 38:	learn: 3965.1209105	total: 38ms	remaining: 35.1ms
# 39:	learn: 3952.5473930	total: 39.2ms	remaining: 34.3ms
# 40:	learn: 3937.4699767	total: 40.3ms	remaining: 33.4ms
# 41:	learn: 3924.9838481	total: 41.3ms	remaining: 32.5ms
# 42:	learn: 3912.1766758	total: 42.5ms	remaining: 31.6ms
# 43:	learn: 3901.4083484	total: 43.6ms	remaining: 30.7ms
# 44:	learn: 3891.5193923	total: 44.7ms	remaining: 29.8ms
# 45:	learn: 3884.3862885	total: 45.8ms	remaining: 28.9ms
# 46:	learn: 3874.0169627	total: 46.8ms	remaining: 27.9ms
# 47:	learn: 3861.4800243	total: 48ms	remaining: 27ms
# 48:	learn: 3855.0540872	total: 49.1ms	remaining: 26ms
# 49:	learn: 3840.8932737	total: 50.3ms	remaining: 25.2ms
# 50:	learn: 3828.0063204	total: 51.5ms	remaining: 24.2ms
# 51:	learn: 3820.2799822	total: 52.6ms	remaining: 23.3ms
# 52:	learn: 3804.9102638	total: 53.7ms	remaining: 22.3ms
# 53:	learn: 3796.6142749	total: 54.8ms	remaining: 21.3ms
# 54:	learn: 3789.8476485	total: 56ms	remaining: 20.3ms
# 55:	learn: 3782.8154920	total: 57.1ms	remaining: 19.4ms
# 56:	learn: 3768.8449736	total: 58.1ms	remaining: 18.4ms
# 57:	learn: 3752.5291935	total: 59.2ms	remaining: 17.4ms
# 58:	learn: 3744.7749350	total: 60.4ms	remaining: 16.4ms
# 59:	learn: 3735.9206806	total: 61.5ms	remaining: 15.4ms
# 60:	learn: 3723.3598318	total: 62.6ms	remaining: 14.4ms
# 61:	learn: 3714.7763022	total: 63.7ms	remaining: 13.4ms
# 62:	learn: 3699.7825651	total: 64.8ms	remaining: 12.3ms
# 63:	learn: 3693.9993387	total: 65.9ms	remaining: 11.3ms
# 64:	learn: 3686.3481415	total: 67ms	remaining: 10.3ms
# 65:	learn: 3675.1618825	total: 68.1ms	remaining: 9.29ms
# 66:	learn: 3669.2045506	total: 69.2ms	remaining: 8.26ms
# 67:	learn: 3665.3069991	total: 70.5ms	remaining: 7.25ms
# 68:	learn: 3657.1966596	total: 71.6ms	remaining: 6.22ms
# 69:	learn: 3648.8930870	total: 72.7ms	remaining: 5.19ms
# 70:	learn: 3643.4685252	total: 73.7ms	remaining: 4.15ms
# 71:	learn: 3633.8757236	total: 76.4ms	remaining: 3.18ms
# 72:	learn: 3628.5975019	total: 78.3ms	remaining: 2.14ms
# 73:	learn: 3618.4934181	total: 80.7ms	remaining: 1.09ms
# 74:	learn: 3607.7052643	total: 82ms	remaining: 0us

# %%
print(f"Coeficiente R² médio: {resultado.mean()}")
print(f"Coeficiente R² inferior: {resultado.mean() - resultado.std()}")
print(f"Coeficiente R² superior: {resultado.mean() + resultado.std()}")
# Out:
# Coeficiente R² médio: 0.8483613861522021
# Coeficiente R² inferior: 0.8063578667102363
# Coeficiente R² superior: 0.8903649055941679

# %% [markdown]
# #### Conclusão

# %% [markdown]
# O XGBoost e o LightGBM foram superiores ao CatBoost.

# %%
model_performance = pd.DataFrame({
  'model': ['catboost'],
  'train_score': [score_treino],
  'test_score': [score_teste],
  'rmse': [rmse],
  'mean_R^2': [resultado.mean()],
  'R^2_std_dev': [resultado.std()]
})
resultados_finais_df = pd.concat([resultados_finais_df, model_performance], ignore_index = False)
resultados_finais_df
# Out:
#                         model  train_score  test_score         rmse  mean_R^2  \
# 0  multiple_linear_regression     0.730957    0.790916  5774.296306  0.735637
# 0    support_vector_regressor     0.837493    0.875260  4460.061407  0.835645
# 0     decision_tree_regressor     0.853165    0.885478  4273.490975  0.851014
# 0               random_forest     0.904702    0.879819  4377.798554  0.850206
# 0                     xgboost     0.881346    0.890161  4185.203997  0.857718
# 0                    lightgbm     0.873667    0.893728  4116.693574  0.857448
# 0                    catboost     0.895974    0.887189  4241.458105  0.848361
#
#    R^2_std_dev
# 0     0.055520
# 0     0.047572
# 0     0.036852
# 0     0.042763
# 0     0.039639
# 0     0.039383
# 0     0.042004

# %% [markdown]
# ### Conclusão Final

# %% [markdown]
# De todos os modelos que foram treinados, os que se saíram melhor foram XGBoost e LightGBM. Ambos conseguiram boas pontuações, mas em termos produtivos, é provável que o LightGBM seria melhor por consumir menos recursos computacionais devido às podas que faz internamente. Com isso, seria o modelo que eu escolheria para produção.
